# %% [markdown]
# ### First, copy the default config and edit it
# For example: change the number of steps to 10,000

# %%
from pathlib import Path
from event_horyzen import event_horyzen

dest = Path("./foo.yml")
event_horyzen.copy_default_config(dest)

# Now edit the file and save it!
# Out:
# Copied default configuration to foo.yml

# %% [markdown]
# ### Tell `event_horyzen` which configuration file(s) you want to use

# %%
conf_path = Path('./foo.yml')
event_horyzen.run(conf_path)
# Out:
# Output saved in output/2021-12-31T214418_foo

# %%
import pickle as pl

# The directory below will need to be fixed for your run!
# The timestamp will be different.
plot_path = Path("output/2021-12-31T214418_foo/basic-plot.pickle")

with open(plot_path, "rb") as plot:
    fig = pl.load(plot)

# Now do whatever you want with the figure!
fig.axes[0].set_title("This is a title")
fig.show()
# Out:
# /tmp/ipykernel_104394/3491369032.py:10: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Multiple simulations can be run in parallel! See the GitHub repo https://github.com/UCF-SPS-Research-21/event-horyzen for an example
#
# ### Below is an example of the 3D plotting module. This can also be run with multiple geodesics at once! See the GitHub.
#
# _This doesn't work on Binder, but it will work locally_

# %%
from event_horyzen import animated_plot as ap

# The directory below will need to be fixed for your run!
# The timestamp will be different.
results = Path("output/2021-12-31T214418_foo/results.h5")
viz = ap.Visualizer(results)
viz.animation()
